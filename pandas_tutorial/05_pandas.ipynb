# %% [markdown]
# ### Column Tranformation - Part 1

# %%
import pandas as pd


df = pd.read_excel("salary.xlsm")
print(df)

# df.loc[(df[" Bonus"] == 0), "Get Bonus"] = "no bonus"
# df.loc[(df[" Bonus"] > 0), "Get Bonus"] = "bonus"
# print(df.head(10))
# Out:
#                 1                        2         3     4   \
# 0              NaN                      NaN       NaN   NaN
# 1             Name              Designation     Month  Year
# 2       Raj Sharma  Chief Technical Officer  December  2016
# 3    Sharad Gandhi               Accountant  December  2016
# 4   Danish D'Souza     Senior Web Developer  December  2016
# 5      Pawan Patil   Senior Ux/Ui Developer  December  2016
# 6        Rijo Paul     Senior Web Developer  December  2016
# 7         Joseph P     Senior Web Developer  December  2016
# 8     Aakash Patel            Web Developer  December  2016
# 9      Ganesh Rahu           Ux/Ui Designer  December  2016
# 10     Vinudas K.S            Web Developer  December  2016
# 11     Divya Kumar            Web Developer  December  2016
# 12        Shilpa R                      QAA  December  2016
# 13      Sindhu J.P            Web Developer  December  2016
# 14     Deepthi P.S                      QAA  December  2016
# ...

# %%
data = pd.read_excel("practise-1.xlsx")
print(data)
data["Full Name"] = data["First Name"].str.capitalize() + " " + data["Last Name"].str.capitalize()
print(data)
# Out:
#    Unnamed: 0 First Name Last Name  Salary EEID
# 0           0      krish      naik  209090   E1
# 1           1  mallanath      mise  299090   E2
# 2           3      lingu     mokte  809090   E3
# 3           4    sandhya      mise  709090   E4
# 4           5     pintu    thakkur  409090   E5
#    Unnamed: 0 First Name Last Name  Salary EEID       Full Name
# 0           0      krish      naik  209090   E1      Krish Naik
# 1           1  mallanath      mise  299090   E2  Mallanath Mise
# 2           3      lingu     mokte  809090   E3     Lingu Mokte
# 3           4    sandhya      mise  709090   E4    Sandhya Mise
# 4           5     pintu    thakkur  409090   E5  Pintu  Thakkur
